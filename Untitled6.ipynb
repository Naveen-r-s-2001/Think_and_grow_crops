# %%
import tkinter as tk
from PIL import Image, ImageTk

# %%
root = tk.Tk()
root.title("title")
root.geometry("800x800")
data = "rice"
content =""

if data=='rice':
    content = "There are three seasons for growing rice in India viz.- autumn, winter and summer\n The Autumn (pre-kharif) rice sowing cycle is May to August and it is harvested in September to October.\nThe winter (kharif) rice sowing cycle is June-July and it is harvested in November to December.\nThe summer(rabi) rice sowing cycle is November to February and it is harvested in March to June. "
if data=='wheat':
    content=""
    
if data=='Mung Bean':
    content=""
    
if data=='Tea':
    content=""
    
if data=='millet':
    content=""
    
if data=='Lentil':
    content=""
    
if data=='Jute':
    content=""
    
if data=='Coffee':
    content=""
    
if data=='Ground Nut':
    content=""
    
if data=='Peas':
    content=""
    
if data=='Rubber':
    content=""
    
if data=='Sugarcane':
    content=""
    
if data=='Tobacco':
    content=""
    
if data=='Kidney Beans':
    content=""
    
if data=='Moth Beans':
    content=""
    
if data=='Coconut':
    content=""
    
if data=='Black gram':
    content=""

if data=='Adzuki Beans':
    content=""
    
if data=='Pigeon Peas':
    content=""
    
if data=='Chickpea':
    content=""
    
if data=='banana':
    content=""
    
if data=='grapes':
    content=""
    
if data=='apple':
    content=""
    
if data=='mango':
    content=""
    
if data=='muskmelon':
    content=""
    
if data=='orange':
    content=""
    
if data=='papaya':
    content=""
    
if data=='pomegranate':
    content=""
    
if data=='watermelon':
    content=""
    





photo = Image.open(r"C:\Users\NAVEEN\Downloads\rice.jpg")
resized_image = photo.resize((500,500),Image.ANTIALIAS)
converted_image = ImageTk.PhotoImage(resized_image)
content ="Rice is the seed of the grass species Oryza sativa (Asian rice) or\n less commonly Oryza glaberrima (African rice). The name wild rice is usually used for species of the genera Zizania and Porteresia,\n both wild and domesticated, although the term may also be used for primitive or uncultivated varieties of Oryza.\nAs a cereal grain, domesticated rice is the most widely consumed staple food for over half of the world's human population,[Liu 1] especially in Asia and Africa. It is the agricultural commodity with the third-highest worldwide production, after sugarcane and maize.[1] Since sizable portions of sugarcane and maize crops are used for purposes other than human consumption, rice is the most important food crop with regard to human nutrition and caloric intake, providing more than one-fifth of the calories consumed worldwide by humans.[2] There are many varieties of rice and culinary preferences tend to vary regionally."



label1 = tk.Label(root,image=converted_image,width=500,height=500)
label2 = tk.Label(root,text=content,width=1000,height=1000)
label1.pack()
label2.pack()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-8-d6af649f8ba7> in <module>
#     103
#     104
# --> 105 label1 = tk.Label(root,image=converted_image,width=500,height=500)
#     106 label2 = tk.Label(root,text=content,width=1000,height=1000)
#     107 label1.pack()
#
# ~\anaconda3\lib\tkinter\__init__.py in __init__(self, master, cnf, **kw)
#    3146
#    3147         """
# -> 3148         Widget.__init__(self, master, 'label', cnf, kw)
#    3149
#    3150
#
# ~\anaconda3\lib\tkinter\__init__.py in __init__(self, master, widgetName, cnf, kw, extra)
#    2570         for k, v in classes:
#    2571             del cnf[k]
# -> 2572         self.tk.call(
#    2573             (widgetName, self._w) + extra + self._options(cnf))
#    2574         for k, v in classes:
#
# TclError: image "pyimage6" doesn't exist
